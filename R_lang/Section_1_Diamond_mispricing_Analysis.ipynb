# %% [markdown]
# Task : Analysis below task using given Data(P2-Mispriced-Diamonds.csv).
# 1. Does a better clearity always mean that diamond is price high.
# 2. Does that relationship some times hold true and are there mispricing in the market?

# %%
mydf<-read.csv("P2-Mispriced-Diamonds.csv")
head(df)
# Out:
#   carat clarity price
# 1 0.23  SI2     326
# 2 0.21  SI1     326
# 3 0.23  VS1     327
# 4 0.29  VS2     334
# 5 0.31  SI2     335
# 6 0.24  VVS2    336

# %%
# Check the structure and Summary
str(mydf)
# Out:
# 'data.frame':	53940 obs. of  3 variables:
#  $ carat  : num  0.23 0.21 0.23 0.29 0.31 0.24 0.24 0.26 0.22 0.23 ...
#  $ clarity: Factor w/ 8 levels "I1","IF","SI1",..: 4 3 5 6 4 8 7 3 6 5 ...
#  $ price  : int  326 326 327 334 335 336 336 337 337 338 ...

# %%
#Summary
summary(mydf)
# Out:
#      carat           clarity          price
#  Min.   :0.2000   SI1    :13065   Min.   :  326
#  1st Qu.:0.4000   VS2    :12258   1st Qu.:  950
#  Median :0.7000   SI2    : 9194   Median : 2401
#  Mean   :0.7979   VS1    : 8171   Mean   : 3933
#  3rd Qu.:1.0400   VVS2   : 5066   3rd Qu.: 5324
#  Max.   :5.0100   VVS1   : 3655   Max.   :18823
#                   (Other): 2531

# %%
runif(mydf)
# Out:
# [1] 0.6159269 0.3519353 0.3441948

# %%
library("ggplot2")

# %%
ggplot(data=mydf, aes(x=carat, y=price))+geom_point()
# Out:
# plot without title

# %%
#TO Make it clear it's use a filter in to data set
ggplot(data=df[df$carat<2.5,],aes(x=carat,y=price,color=clarity))+geom_point(alpha=0.1)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# ## Conclusion:
# 1.lF Brown color line shows best clearity and with the high price as well So Diamond with the best clarity having high price
# 2. But where ever these line crossing each other means it shows mispricing
