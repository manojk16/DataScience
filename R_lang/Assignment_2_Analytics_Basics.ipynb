# %%
#1.	Write R code using data “IMDB_data” to
#  a.Load CSV in R by skipping second row.

# %%
Sys.getlocale()
# Out:
# [1] "LC_CTYPE=C;LC_NUMERIC=C;LC_TIME=en_US.UTF-8;LC_COLLATE=en_US.UTF-8;LC_MONETARY=en_US.UTF-8;LC_MESSAGES=en_US.UTF-8;LC_PAPER=en_US.UTF-8;LC_NAME=C;LC_ADDRESS=C;LC_TELEPHONE=C;LC_MEASUREMENT=en_US.UTF-8;LC_IDENTIFICATION=C"

# %%
Sys.setlocale(category = "LC_CTYPE", locale = "C")
#You may have encountered this issue because of the incompatibility of system locale try setting the system locale with this code Sys.setlocale("LC_ALL", "C")
# Out:
# [1] "C"

# %%
df=read.csv("IMDB_data.csv")[-2]

# %%
colnames(df)
# Out:
# [1] "Plot"         "imdbVotes"    "Poster"       "imdbRating"   "Genre"
# [6] "imdbID"       "Year"         "Language"     "new_Variable"

# %%
#df$imdbVotes-df$imdbRating
df$imdbVotes=as.numeric(df$imdbVotes)
df$imdbRating=as.numeric(df$imdbRating)
df$new_Variable=df$imdbRating-df$imdbVotes
df$new_Variable
head(df)
# Out:
#    [1] -604    0  -64 -615 -300 -308 -198 -647 -315 -435 -338 -606 -606 -606
#   [15] -606 -606 -606 -606 -606 -301 -606 -606 -606 -606 -606   -8 -518 -606
#   [29] -553 -606 -606 -606 -443 -309 -492 -562 -418 -334 -606  -54 -606 -606
#   [43] -648 -606 -606 -339 -606 -501 -285 -520 -446 -498  -63 -155 -290 -323
#   [57] -265 -606  -53  -77  -30 -410 -350 -209 -390   -3 -208 -467 -288  -87
#   [71]  -20 -606 -446 -534 -579 -525 -323 -614 -427 -201 -382 -483 -343 -614
#   [85] -433 -112 -202  -82 -464 -606 -606 -173 -229 -388 -157  -29 -471 -319
#   [99] -456  -37 -332 -549 -606 -606 -606 -606 -606 -606 -606 -338 -606 -606
#  [113] -541  -18 -222 -132 -333 -606 -480 -361 -349 -500  -41 -188 -187 -398
#  [127] -187 -570 -239 -505 -396 -234 -557 -329 -606  -86  -20 -606 -606 -606
#  [141] -606 -606 -617 -606 -606 -606 -606 -614 -606 -594 -606 -404 -606 -502
#  [155] -467 -639 -596  -10 -655 -153 -591 -663 -549 -375 -185 -551 -312  -74
# ...

# %%
ncol(df)
# Out:
# [1] 9

# %%
str(df)
# Out:
# 'data.frame':	3389 obs. of  9 variables:
#  $ Plot      : Factor w/ 3382 levels "' I Like You' is an honest and raw depiction of teenage life in Reno, Nevada. It takes an unfiltered look at th"| __truncated__,..: 68 1081 2115 3219 843 497 1719 2102 1683 1760 ...
#  $ Title     : Factor w/ 3383 levels "0","1 world 100 lonely",..: 1 2894 1649 2369 2352 2707 2247 2482 251 2778 ...
#  $ imdbVotes : Factor w/ 905 levels "","-","0","1,016",..: 3 132 643 355 363 245 678 365 468 374 ...
#  $ Poster    : Factor w/ 1783 levels "0","http://i.media-imdb.com/images/SF1f0a42ee1aa08d477a576fbbf7562eed/realm/feature.gif",..: 1 1457 1165 101 936 432 813 1207 1193 1519 ...
#  $ imdbRating: Factor w/ 89 levels "","-","0","2.5",..: 3 68 28 55 55 47 32 50 33 36 ...
#  $ Genre     : Factor w/ 250 levels "0","Action","Action, Adventure",..: 1 195 124 87 134 134 159 134 195 107 ...
#  $ imdbID    : Factor w/ 3383 levels "0","tt0016004",..: 1 609 784 417 411 681 582 1137 694 519 ...
# ...

# %%
summary(df)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
?summary
# Out:
# summary                  package:base                  R Documentation
#
# s
#
# n:
#
#      'summary' is a generic function used to produce result summaries
#      of the results of various model fitting functions.  The function
#      invokes particular 'methods' which depend on the 'class' of the
#      first argument.
#
# e:
#
#      summary(object, ...)
#
#      ## Default S3 method:
#      summary(object, ..., digits)
#      ## S3 method for class 'data.frame'
#      summary(object, maxsum = 7,
#             digits = max(3, getOption("digits")-3), ...)
#
#      ## S3 method for class 'factor'
#      summary(object, maxsum = 100, ...)
#
#      ## S3 method for class 'matrix'
#      summary(object, ...)
#
#      ## S3 method for class 'summaryDefault'
#      format(x, digits = max(3L, getOption("digits") - 3L), ...)
#       ## S3 method for class 'summaryDefault'
#      print(x, digits = max(3L, getOption("digits") - 3L), ...)
#
# s:
#
# ...
